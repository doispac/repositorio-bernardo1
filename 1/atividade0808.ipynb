# %%
import pandas as pd
import numpy as np

# %%
num_rows = 50

data = {
'Produto': [f'Produto_{i}' for i in range(1, num_rows + 1)],
'Categoria': np.random.choice(['Televisão', 'Computador','Celular', 'Tabela', 'Impressora'], size=num_rows),
'Preço':np.random.uniform(100.0,2000.0, size=num_rows).round(2),
'Quantidade_Estoque':np.random.randint(1,50,size=num_rows)
}

# %%
df = pd.DataFrame(data)
df

# %%
df['Multiplicar'] = df['Preço']* df['Quantidade_Estoque']
df

# %%
def mult(x):
    return x ['Quantidade_Estoque'] * x ['Preço']

# %%
df['Multiplicar2'] = df.apply(mult,axis=1)
df
# Out:
#        Produto   Categoria    Preço  Quantidade_Estoque  Multiplicar  \
# 0    Produto_1  Impressora  1356.70                  40     54268.00
# 1    Produto_2  Impressora  1736.61                  45     78147.45
# 2    Produto_3  Computador  1075.58                  42     45174.36
# 3    Produto_4  Computador   487.81                  42     20488.02
# 4    Produto_5     Celular  1405.52                  40     56220.80
# 5    Produto_6      Tabela   698.96                  11      7688.56
# 6    Produto_7     Celular   300.93                  39     11736.27
# 7    Produto_8      Tabela   201.54                  24      4836.96
# 8    Produto_9      Tabela  1476.68                  28     41347.04
# 9   Produto_10   Televisão   232.99                  47     10950.53
# 10  Produto_11      Tabela  1136.86                   7      7958.02
# 11  Produto_12  Impressora   746.47                  24     17915.28
# 12  Produto_13     Celular   766.37                  20     15327.40
# 13  Produto_14  Computador   504.60                   4      2018.40
# 14  Produto_15  Impressora   570.79                  35     19977.65
# 15  Produto_16  Impressora  1245.55                  18     22419.90
# 16  Produto_17  Impressora  1641.71                  41     67310.11
# 17  Produto_18  Computador  1361.81                  11     14979.91
# 18  Produto_19  Impressora   327.73                  43     14092.39
# 19  Produto_20  Impressora   708.23                  30     21246.90
# 20  Produto_21   Televisão   217.66                  30      6529.80
# 21  Produto_22   Televisão  1530.77                   7     10715.39
# 22  Produto_23  Impressora   215.86                  38      8202.68
# 23  Produto_24     Celular   149.67                   8      1197.36
# 24  Produto_25     Celular   247.85                  24      5948.40
# 25  Produto_26   Televisão   642.44                  24     15418.56
# 26  Produto_27   Televisão  1104.42                  41     45281.22
# 27  Produto_28      Tabela   352.79                  11      3880.69
# 28  Produto_29  Impressora   755.96                  46     34774.16
# 29  Produto_30      Tabela   800.51                  30     24015.30
# 30  Produto_31   Televisão   866.84                   2      1733.68
# 31  Produto_32  Computador   462.11                  28     12939.08
# 32  Produto_33     Celular   658.41                  22     14485.02
# 33  Produto_34      Tabela   296.28                  15      4444.20
# 34  Produto_35  Computador  1824.76                  38     69340.88
# 35  Produto_36   Televisão   917.51                  49     44957.99
# 36  Produto_37      Tabela   391.76                  33     12928.08
# 37  Produto_38     Celular  1633.39                  12     19600.68
# 38  Produto_39      Tabela   531.83                  33     17550.39
# 39  Produto_40   Televisão  1716.90                  37     63525.30
# 40  Produto_41   Televisão   326.88                   3       980.64
# 41  Produto_42      Tabela   790.22                   5      3951.10
# 42  Produto_43  Impressora  1082.19                  37     40041.03
# 43  Produto_44      Tabela   324.23                  25      8105.75
# 44  Produto_45  Impressora  1904.92                  25     47623.00
# 45  Produto_46  Computador  1200.97                  47     56445.59
# 46  Produto_47     Celular   582.43                  37     21549.91
# 47  Produto_48      Tabela   727.95                  22     16014.90
# 48  Produto_49  Computador  1599.72                  36     57589.92
# 49  Produto_50  Impressora   414.42                   2       828.84
#
#     Multiplicar2
# 0       54268.00
# 1       78147.45
# 2       45174.36
# 3       20488.02
# 4       56220.80
# 5        7688.56
# 6       11736.27
# 7        4836.96
# 8       41347.04
# 9       10950.53
# 10       7958.02
# 11      17915.28
# 12      15327.40
# 13       2018.40
# 14      19977.65
# 15      22419.90
# 16      67310.11
# 17      14979.91
# 18      14092.39
# 19      21246.90
# 20       6529.80
# 21      10715.39
# 22       8202.68
# 23       1197.36
# 24       5948.40
# 25      15418.56
# 26      45281.22
# 27       3880.69
# 28      34774.16
# 29      24015.30
# 30       1733.68
# 31      12939.08
# 32      14485.02
# 33       4444.20
# 34      69340.88
# 35      44957.99
# 36      12928.08
# 37      19600.68
# 38      17550.39
# 39      63525.30
# 40        980.64
# 41       3951.10
# 42      40041.03
# 43       8105.75
# 44      47623.00
# 45      56445.59
# 46      21549.91
# 47      16014.90
# 48      57589.92
# 49        828.84
