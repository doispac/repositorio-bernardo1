# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
caminho_arquivo = r'C:\Users\bernardo_b_garcia\Downloads\correcao_bugs_classificacao.xlsx'
df_correcao = pd.read_excel(caminho_arquivo)

# %%
df_correcao
# Out:
#               Localização do Bug Sistema Operacional  Versão do Software  \
# 0                       Frontend             Windows                 2.0
# 1                        Backend               Linux                 2.0
# 2                 Banco de Dados             Windows                 1.0
# 3           Integrações Externas               Linux                 1.0
# 4       Configuração do Ambiente             Windows                 2.0
# 5                      Segurança               Linux                 1.0
# 6                    Performance             Windows                 1.0
# 7                          UI/UX               Linux                 2.0
# 8   Compatibilidade de Navegador             Windows                 1.0
# 9                         Mobile               Linux                 1.0
# 10                      Frontend             Windows                 2.0
# 11                       Backend               Linux                 1.0
# ...

# %%
mapeamento_complexidade = {'Simples':0,'Moderada':1,'Complexa':2}

# %%
df_correcao['Complexidade do Bug'] = df_correcao['Complexidade do Bug'].map(mapeamento_complexidade)
df_correcao
# Out:
#               Localização do Bug Sistema Operacional  Versão do Software  \
# 0                       Frontend             Windows                 2.0
# 1                        Backend               Linux                 2.0
# 2                 Banco de Dados             Windows                 1.0
# 3           Integrações Externas               Linux                 1.0
# 4       Configuração do Ambiente             Windows                 2.0
# 5                      Segurança               Linux                 1.0
# 6                    Performance             Windows                 1.0
# 7                          UI/UX               Linux                 2.0
# 8   Compatibilidade de Navegador             Windows                 1.0
# 9                         Mobile               Linux                 1.0
# 10                      Frontend             Windows                 2.0
# 11                       Backend               Linux                 1.0
# ...
