# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
n_samples = 50

# %%
data = {
    'Data': pd.date_range(start='2023-01-01', periods=n_samples, freq='D'),
    'Vendas': np.random.randint(50,200, size=n_samples),
    'Lucro': np.random.randint(10,50, size=n_samples)
}

# %%
df = pd.DataFrame(data)
df
# Out:
#          Data  Vendas  Lucro
# 0  2023-01-01     149     47
# 1  2023-01-02     192     27
# 2  2023-01-03     115     49
# 3  2023-01-04      95     39
# 4  2023-01-05      69     34
# 5  2023-01-06     169     42
# 6  2023-01-07     186     25
# 7  2023-01-08     116     47
# 8  2023-01-09     139     19
# 9  2023-01-10     154     27
# 10 2023-01-11     142     27
# 11 2023-01-12     120     43
# 12 2023-01-13     182     47
# 13 2023-01-14      93     16
# 14 2023-01-15     109     11
# 15 2023-01-16      64     48
# 16 2023-01-17      52     38
# 17 2023-01-18     107     28
# 18 2023-01-19      67     32
# 19 2023-01-20      82     48
# 20 2023-01-21     188     39
# 21 2023-01-22     115     22
# 22 2023-01-23      61     23
# 23 2023-01-24      57     19
# 24 2023-01-25      83     11
# 25 2023-01-26     182     12
# 26 2023-01-27     188     24
# 27 2023-01-28      83     30
# 28 2023-01-29      72     13
# 29 2023-01-30     166     25
# 30 2023-01-31      95     35
# 31 2023-02-01     199     12
# 32 2023-02-02     131     34
# 33 2023-02-03     181     22
# 34 2023-02-04     139     42
# 35 2023-02-05     175     28
# 36 2023-02-06      66     38
# 37 2023-02-07     195     15
# 38 2023-02-08      93     35
# 39 2023-02-09      89     31
# 40 2023-02-10      77     26
# 41 2023-02-11     124     12
# 42 2023-02-12     144     19
# 43 2023-02-13      82     31
# 44 2023-02-14     199     38
# 45 2023-02-15      77     25
# 46 2023-02-16     145     19
# 47 2023-02-17     125     12
# 48 2023-02-18     190     17
# 49 2023-02-19      67     34

# %%
df['Margem'] = df['Lucro'] / df['Vendas']

# %%
df['Margem'].min()
# Out:
# np.float64(0.06030150753768844)

# %%
df['Margem'].max()
# Out:
# np.float64(0.75)

# %%
plt.figure(figsize=(10,6))
plt.plot(df['Data'],df['Vendas'],marker='o', linestyle='-',color='black')
